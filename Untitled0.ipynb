# %% [markdown]
# <a href="https://colab.research.google.com/github/dk8159969-ui/phyton/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Item_1="pizza"
price_of_item_1=200
item_2="samosha"
price_of_item_2=20
item_3="burger"
price_of_item_3=50
total_expense=price_of_item_1+price_of_item_2+price_of_item_3
print("total expence",total_expense)
print("price_of_item_1",price_of_item_1)
print("price_of_item_2",price_of_item_2)
print("price_of_item_3",price_of_item_3)
discount_perecent=20
discount=total_expense*discount_perecent/100
print("discount",discount)
payble_bill = total_expence - discount
print("payble_bill",payble_bill)
# Out:
# total expence 270
# price_of_item_1 200
# price_of_item_2 20
# price_of_item_3 50
# discount 54.0
# payble_bill 216.0
