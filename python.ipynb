# %% [markdown]
# <a href="https://colab.research.google.com/github/dk8159969-ui/phyton/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hi i am deepak
print("        BioData      ")
print("name  :  depak")
print("age  :   28")
print("phone no   :    9876543321")
print("Address   :    Chandighar")
print("pincord   :     176080")
print("course    :     Data Anlyst")
print("Location  :     sector 32A")
print("subject   :     Phyton")
# Out:
#         BioData
# name  :  depak
# age  :   28
# phone no   :    9876543321
# Address   :    Chandighar
# pincord   :     176080
# course    :     Data Anlyst
# Location  :     sector 32A
# subject   :     Phyton

# %%
name="Rahul"
age =40
phone_no=9876543321
Address="Chandigarh"
pincord=176080
course="Data Anlyst"
Location="sector 32A"
subject="Phyton"
print("name  :", name)
print("age : ", age)
print("phone  :", phone_no)
print("adress : ", Address)
print("pincord  :",pincord)
print("course :",course)
print("location  :",Location)
print("subject   :",subject)
# Out:
# name  : Rahul
# age :  40
# phone  : 9876543321
# adress :  Chandigarh
# pincord  : 176080
# course : Data Anlyst
# location  : sector 32A
# subject   : Phyton

# %%
Name="Rahul"
print("name   :",Name)
Address="Mohali"
print("adress  :",Address)
Location="Cp 67"
print("location :",Location)
Subject="phyton"
print("subject :",Subject)
pincord="176080"
print("pincord  :",pincord)
# Out:
# name   : Rahul
# adress  : Mohali
# location : Cp 67
# subject : phyton
# pincord  : 176080
